# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/owenwinters/Documents/Tech Talent South/TTS.Student-main/datascience/python/10_mod_pandas/Corey Schafer Pandas Tutorial Video Data/survey_results_public.csv', index_col='ResponseId')

# %%
df.head(10)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 6                      I am a student who is learning to code
# 7                                 I code primarily as a hobby
# 8                      I am a student who is learning to code
# 9                              I am a developer by profession
# 10                             I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# ...

# %%
df.shape
# Out:
# (83439, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('/Users/owenwinters/Documents/Tech Talent South/TTS.Student-main/datascience/python/10_mod_pandas/Corey Schafer Pandas Tutorial Video Data/survey_results_schema.csv', index_col='qname')

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
type(df['EdLevel'])
#df is 2 dimensional (rows + columns)
#a df is a container for series. A series is rows of a single column
# Out:
# pandas.core.series.Series

# %%
df.loc[1]
# Out:
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# DevType                                                         Developer, mobile
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.iloc[[0, 1], 2]
#integer location
#2nd arg outside of the first brackets is for columns
# Out:
# ResponseId
# 1       Slovakia
# 2    Netherlands
# Name: Country, dtype: object

# %%
df.loc[[0,1], ['EdLevel', 'Employment']]
#use labels for loc columns
#returns a df with columns in order you specify
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-74afcc43d1b8> in <module>
# ----> 1 df.loc[[0,1], ['EdLevel', 'Employment']]
#       2 #use labels for loc columns
#       3 #returns a df with columns in order you specify
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1065         # ugly hack for GH #836
#    1066         if self._multi_take_opportunity(tup):
# ...

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          35357
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       17512
# Some college/university study without earning a degree                                10589
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     9534
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2567
# Primary/elementary school                                                              2479
# Associate degree (A.A., A.S., etc.)                                                    2231
# Something else                                                                         1601
# Professional degree (JD, MD, etc.)                                                     1256
# Name: EdLevel, dtype: int64

# %%
df.loc[0:2, 'Employment':'EdLevel']
# Out:
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State UK_Country  \
# ResponseId
# 1               NaN        NaN
# 2               NaN        NaN
#
#                                                       EdLevel
# ResponseId
# 1           Secondary school (e.g. American high school, G...
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)

# %%
df.set_index('EdLevel', inplace=True)

# %%
df.index
# Out:
# Index(['Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#                                              'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#                                              'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#                                           'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#                                           'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#                                              'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#                                              'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#                                              'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#                                           'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        ...
# ...

# %%
df.loc['Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)']
# Out:
#                                                                                 MainBranch  \
# EdLevel
# Secondary school (e.g. American high school, Ge...          I am a developer by profession
# Secondary school (e.g. American high school, Ge...             I code primarily as a hobby
# Secondary school (e.g. American high school, Ge...  I am a student who is learning to code
# Secondary school (e.g. American high school, Ge...          I am a developer by profession
# Secondary school (e.g. American high school, Ge...          I am a developer by profession
# ...                                                                                    ...
# Secondary school (e.g. American high school, Ge...          I am a developer by profession
# Secondary school (e.g. American high school, Ge...  I am a student who is learning to code
# Secondary school (e.g. American high school, Ge...             I code primarily as a hobby
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                  EdLevel  \
# 0      Secondary school (e.g. American high school, G...
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                  ...
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436  Secondary school (e.g. American high school, G...
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438                 Professional degree (JD, MD, etc.)
#
#                                               MainBranch  \
# 0                         I am a developer by profession
# 1                 I am a student who is learning to code
# 2      I am not primarily a developer, but I write co...
# ...

# %%
schema_df.loc['NEWStuck', 'question']
# Out:
# 'What do you do when you get stuck on a problem? Select all that apply.'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %%
filt = (df['Gender'] == 'Woman') | (df['Employment'] == 'Employed full-time')

# %%
df.loc[filt]
#can put filter directly in here e.g. df[df['Gender'] == 'Woman']
# Out:
#                                                  EdLevel  \
# 3        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 83432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436  Secondary school (e.g. American high school, G...
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438                 Professional degree (JD, MD, etc.)
#
#                                    MainBranch          Employment  \
# 3              I am a developer by profession  Employed full-time
# 7      I am a student who is learning to code  Student, full-time
# 9              I am a developer by profession  Employed full-time
# ...

# %%
df.loc[filt, 'EdLevel']
#can also use .loc with booleans (used as filters in this scenario)
#~ is opposite of filter
# Out:
# 3          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 7             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#                                ...
# 83432         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83434         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436    Secondary school (e.g. American high school, G...
# 83437         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438                   Professional degree (JD, MD, etc.)
# Name: EdLevel, Length: 55102, dtype: object

# %%
high_salary = (df['CompTotal'] > 10000)
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False) #string method

# %%
df.loc[high_salary, ['Country', 'CompTotal', 'LanguageHaveWorkedWith']]
# Out:
#                         Country  CompTotal  \
# 9                        Sweden    42000.0
# 11                        Spain    43000.0
# 12                      Germany    71500.0
# 17                       Canada    61000.0
# 18                    Singapore    18700.0
# ...                         ...        ...
# 83432                    Canada   106000.0
# 83433                    Brazil    80000.0
# 83434  United States of America   160500.0
# 83435                     Benin   200000.0
# 83437                    Canada    90000.0
#
#                                   LanguageHaveWorkedWith
# 9                                             C++;Python
# 11     Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# 12                                  C;C++;Java;Perl;Ruby
# 17           Bash/Shell;HTML/CSS;JavaScript;PHP;Ruby;SQL
# 18                                            C++;Python
# ...                                                  ...
# ...

# %%
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# 1                                        JavaScript;Python
# 2                                 Assembly;C;Python;R;Rust
# 4                           Bash/Shell;HTML/CSS;Python;SQL
# 5        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 9                                               C++;Python
#                                ...
# 83429               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83436                                   Groovy;Java;Python
# 83437                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %%
filt
#filters return a series of true/false values. when applied to a data frame only the true values appear
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 83434    False
# 83435    False
# 83436     True
# 83437     True
# 83438    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %%
df.columns
# Out:
# Index(['EdLevel', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
#df.columns[''] --> using a list you can rename all of your column names
#df.columns = [x.upper() for x in df.columns] --> using list comprehension you can make all column names uppercase
#df.columns = df.columns.str.replace('_', '') --> replace all underscores with spaces

# %%
df['EdLevel'].str.lower()
# Out:
# 0        secondary school (e.g. american high school, g...
# 1             bachelor’s degree (b.a., b.s., b.eng., etc.)
# 2             bachelor’s degree (b.a., b.s., b.eng., etc.)
# 3          master’s degree (m.a., m.s., m.eng., mba, etc.)
# 4          master’s degree (m.a., m.s., m.eng., mba, etc.)
#                                ...
# 83434         bachelor’s degree (b.a., b.s., b.eng., etc.)
# 83435         bachelor’s degree (b.a., b.s., b.eng., etc.)
# 83436    secondary school (e.g. american high school, g...
# 83437         bachelor’s degree (b.a., b.s., b.eng., etc.)
# 83438                   professional degree (jd, md, etc.)
# Name: EdLevel, Length: 83439, dtype: object

# %%
#apply - apply a value to every part of a series
#map - only works on a series, replaces all values (NaN if not specified)
#replace - replaces only specified values
#applymap - only works on dataframes (does not work on series objects)

# %%
def update_employment(Employment):
    return Employment.upper()

# %%
df['Employment'].apply(update_employment)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-c4799c5625bf> in <module>
# ----> 1 df['Employment'].apply(update_employment)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-46-b6c46f7872bf> in update_employment(Employment)
#       1 def update_employment(Employment):
# ----> 2     return Employment.upper()
#
# AttributeError: 'float' object has no attribute 'upper'

# %%
df.apply(len)
# Out:
# EdLevel                         83439
# MainBranch                      83439
# Employment                      83439
# Country                         83439
# US_State                        83439
# UK_Country                      83439
# Age1stCode                      83439
# LearnCode                       83439
# YearsCode                       83439
# YearsCodePro                    83439
# DevType                         83439
# OrgSize                         83439
# Currency                        83439
# CompTotal                       83439
# CompFreq                        83439
# LanguageHaveWorkedWith          83439
# LanguageWantToWorkWith          83439
# DatabaseHaveWorkedWith          83439
# DatabaseWantToWorkWith          83439
# PlatformHaveWorkedWith          83439
# PlatformWantToWorkWith          83439
# WebframeHaveWorkedWith          83439
# WebframeWantToWorkWith          83439
# MiscTechHaveWorkedWith          83439
# MiscTechWantToWorkWith          83439
# ...

# %%
df.applymap(min)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-1eb8d5da77ec> in <module>
# ----> 1 df.applymap(min)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in applymap(self, func, na_action)
#    7842             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    7843
# -> 7844         return self.apply(infer).__finalize__(self, "applymap")
#    7845
#    7846     # ----------------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ...

# %%
 df.apply(pd.Series.min)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-4312d437d7fd> in <module>
# ----> 1 df.apply(pd.Series.min)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# ...

# %%
df.rename(columns={'ConvertedCompYearly': 'SalaryUSD'}, inplace = True)

# %%
df['SalaryUSD']
# Out:
# 0         62268.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 83434    160500.0
# 83435      3960.0
# 83436     90000.0
# 83437    816816.0
# 83438     21168.0
# Name: SalaryUSD, Length: 83439, dtype: float64

# %%
df['MainBranch']
# Out:
# 0                           I am a developer by profession
# 1                   I am a student who is learning to code
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 83434                       I am a developer by profession
# 83435                       I am a developer by profession
# 83436                       I am a developer by profession
# 83437                       I am a developer by profession
# 83438                       I am a developer by profession
# Name: MainBranch, Length: 83439, dtype: object

# %%
df['SOAccount'].replace({'Yes': True, 'No': False})
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 83434    False
# 83435     True
# 83436     True
# 83437     True
# 83438     True
# Name: SOAccount, Length: 83439, dtype: object

# %%
#part 6
